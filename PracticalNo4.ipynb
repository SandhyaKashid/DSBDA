# %%
import pandas as pd

# %%
df=pd.read_csv('amazon.csv')

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '', regex=False)
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce')

# %%
z = df[['rating','rating_count']]

# %%
df.rating
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# Name: rating, Length: 1465, dtype: float64

# %%
z
# Out:
#       rating  rating_count
# 0        4.2       24269.0
# 1        4.0       43994.0
# 2        3.9        7928.0
# 3        4.2       94363.0
# 4        4.2       16905.0
# ...      ...           ...
# 1460     4.0        1090.0
# 1461     4.1        4118.0
# 1462     3.6         468.0
# 1463     4.0        8031.0
# 1464     4.3        6987.0
#
# [1465 rows x 2 columns]

# %%
df.product_id.min()
# Out:
# 'B002PD61Y4'

# %%
df.product_id.max()
# Out:
# 'B0BR4F878Q'

# %%
df.notnull()
# Out:
#       product_id  product_name  category  discounted_price  actual_price  \
# 0           True          True      True              True          True
# 1           True          True      True              True          True
# 2           True          True      True              True          True
# 3           True          True      True              True          True
# 4           True          True      True              True          True
# ...          ...           ...       ...               ...           ...
# 1460        True          True      True              True          True
# 1461        True          True      True              True          True
# 1462        True          True      True              True          True
# 1463        True          True      True              True          True
# 1464        True          True      True              True          True
#
#       discount_percentage  rating  rating_count  about_product  user_id  \
# ...

# %%
x=pd.notnull(df["rating"])

# %%
x
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: rating, Length: 1465, dtype: bool

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
y=df.fillna(df.product_id.min())

# %%
y
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
scaler = MinMaxScaler()

# %%
x = scaler.fit_transform(z)

# %%
x
# Out:
# array([[0.73333333, 0.05683524],
#        [0.66666667, 0.10303276],
#        [0.63333333, 0.01856332],
#        ...,
#        [0.53333333, 0.00109141],
#        [0.66666667, 0.01880456],
#        [0.76666667, 0.01635942]])

# %%
frame=pd.DataFrame(x,columns=["rating","rating_coun"])

# %%
frame
# Out:
#         rating  rating_coun
# 0     0.733333     0.056835
# 1     0.666667     0.103033
# 2     0.633333     0.018563
# 3     0.733333     0.221001
# 4     0.733333     0.039588
# ...        ...          ...
# 1460  0.666667     0.002548
# 1461  0.700000     0.009640
# 1462  0.533333     0.001091
# 1463  0.666667     0.018805
# 1464  0.766667     0.016359
#
# [1465 rows x 2 columns]
