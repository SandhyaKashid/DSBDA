# %%
import nltk

# %%
nltk.download('punkt') 
nltk.download('stopwords') 
nltk.download('wordnet') 
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Satyam Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
text= "Tokenization is the first step in text analytics. The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization."

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

text = "This is a sentence. This is another sentence."
tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['This is a sentence.', 'This is another sentence.']

# %%
from nltk.tokenize import word_tokenize 
tokenized_word=word_tokenize(text) 
print(tokenized_word)
# Out:
# ['This', 'is', 'a', 'sentence', '.', 'This', 'is', 'another', 'sentence', '.']

# %%
from nltk.corpus import stopwords 
stop_words=set(stopwords.words("english")) 
print(stop_words)
# Out:
# {'isn', "hasn't", 'hers', 'after', 'themselves', "isn't", 'this', "shan't", 'so', "she'll", 'but', 'under', 'by', 'more', "they're", "don't", 'm', 'd', 'had', "didn't", "mightn't", 'should', 'or', 'theirs', 'as', 'and', 'they', 'those', 'from', 'through', "hadn't", 'was', 'wouldn', "you've", 'it', 'did', 'that', 'couldn', 'shouldn', 'myself', 'have', 'at', 'once', 'itself', 'mustn', 'what', 'y', "aren't", 'to', 'haven', "she's", 'mightn', 'its', 'off', "he'll", "you'd", "couldn't", 'below', "i've", 'our', 'again', "he'd", 'not', 'only', "it'll", 'whom', 'yourself', 'i', 'me', 'for', 'ours', "we're", "needn't", 'do', 'him', "weren't", 'now', 'an', 'out', 'between', 'with', 'each', 'before', 'aren', 't', 'where', "wasn't", "i'd", "that'll", 'your', 'on', 'o', 'them', "he's", "they'd", "they'll", 'were', 'doing', "it'd", "they've", 'further', 'why', "should've", 'a', 'both', 'himself', 'nor', "you're", "we'd", 'yourselves', 'few', 'very', 'the', "haven't", 'can', 'just', 'are', "doesn't", 'has', 'be', "she'd", 'any', 'she', 'having', 'during', 'own', "we've", 'you', 'weren', 'herself', 'there', 'yours', 'll', "we'll", 'while', 'don', 'hasn', 'too', 'against', 'will', 'then', 'up', 'than', 'of', 'am', "shouldn't", 'doesn', 'he', 'ourselves', 'his', "wouldn't", 'over', 'here', 's', 'shan', 'we', "i'm", "mustn't", 'no', 'which', 'does', 'above', 'who', 'her', 'being', 'if', 'how', 'hadn', 'because', 'down', 'some', 'ma', 'wasn', "you'll", 'in', 'needn', 'is', 'my', 'when', 're', 'won', 'all', 'didn', 'such', 'been', 'until', "i'll", 'same', "won't", 'their', 'ain', 'about', 'these', "it's", 'most', 've', 'other', 'into'}

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

text = "How to remove stop words with NLTK library in Python?"

text = re.sub('[^a-zA-Z]', ' ', text)

tokens = word_tokenize(text.lower())

stop_words = set(stopwords.words('english'))

filtered_text = []
for w in tokens:
    if w not in stop_words:
        filtered_text.append(w)

print("Tokenized Sentence:", tokens)
print("Filtered Sentence:", filtered_text)
# Out:
# Tokenized Sentence: ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']
# Filtered Sentence: ['remove', 'stop', 'words', 'nltk', 'library', 'python']
# [nltk_data] Downloading package punkt to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

e_words = ["wait", "waiting", "waited", "waits"]

ps = PorterStemmer()

for w in e_words:
    rootWord = ps.stem(w)
    print(rootWord)
# Out:
# wait
# wait
# wait
# wait

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()
text = "studies studying cries cry"
tokens = nltk.word_tokenize(text)
for w in tokens:
    print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry
# [nltk_data] Downloading package punkt to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Satyam
# [nltk_data]     Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Satyam Kashid\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

data = "The pink sweater fit her perfectly"
words = word_tokenize(data)

for word in words:
    print(nltk.pos_tag([word]))
# Out:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]
