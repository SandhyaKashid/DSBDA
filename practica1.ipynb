# %%
meal_cost = float(input("Enter the cost of the meal: $"))

tax_rate = 0.14

tax_amount = meal_cost * tax_rate
tip_amount = meal_cost * 0.18
total_amount = meal_cost + tax_amount + tip_amount

print("Tax: ${:.2f}".format(tax_amount))
print("Tip: ${:.2f}".format(tip_amount))
print("Total: ${:.2f}".format(total_amount))
# Out:
# Enter the cost of the meal: $ 30
# Tax: $4.20
# Tip: $5.40
# Total: $39.60

# %%
name="Sandhya"
mailingaddress="Talegaon Dabhade pune"
print("my name is:{name} and my mailing address is:{email}".format(name=name,email=mailingaddress));
# Out:
# my name is:Sandhya and my mailing address is:Talegaon Dabhade pune

# %%
x=input("Enter yout name:")
print("hello {x}".format(x=x))
# Out:
# Enter yout name: Sandhya
# hello Sandhya

# %%
width = float(input("Enter the width of the room: "))
height = float(input("Enter the height of the room: "))
area = width * height
print("The width of the room is {width} and the height of the room is {height}, ""then the total area of the room is {area}m".format(width=width, height=height, area=area)
)
# Out:
# Enter the width of the room:  40
# Enter the height of the room:  50
# The width of the room is 40.0 and the height of the room is 50.0, then the total area of the room is 2000.0m

# %%
sqperacre = 43560

length = float(input("Enter the length of the field in feet: "))
width = float(input("Enter the width of the field in feet: "))
area = (length * width) / sqperacre
print("The length of the field in feet is {length}, ""the width of the field in feet is {width}, ""and the area of the field in acres is {area}".format(length=length, width=width, area=area))
# Out:
# Enter the length of the field in feet:  80
# Enter the width of the field in feet:  35
# The length of the field in feet is 80.0, the width of the field in feet is 35.0, and the area of the field in acres is 0.0642791551882461

# %%
n=int(input("Enter the first n natural number:"))
sum=n*n+1/2
print("the sum of the first natural number is:{sum}".format(sum=sum))
# Out:
# Enter the first n natural number: 5
# the sum of the first natural number is:25.5
